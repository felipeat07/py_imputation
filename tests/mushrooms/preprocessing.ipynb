# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Caminho para o arquivo CSV
file_path = 'mushrooms_data/agaricus-lepiota.data'

# Lista com os nomes das colunas, conforme a descrição do dataset
columns = [
    'class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
    'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
    'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
    'stalk-surface-below-ring', 'stalk-color-above-ring',
    'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
    'ring-type', 'spore-print-color', 'population', 'habitat'
]

# Leitura do arquivo
df = pd.read_csv(file_path, header=None, names=columns)

# Configurar o pandas para mostrar todas as colunas
pd.set_option('display.max_columns', None)

# Exibir as primeiras 10 linhas com todas as colunas
display(df.head(10))
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
# 5     e         x           y         y       t    a               f
# 6     e         b           s         w       t    a               f
# 7     e         b           y         w       t    l               f
# 8     p         x           y         w       t    p               f
# 9     e         b           s         y       t    a               f
#
#   gill-spacing gill-size gill-color stalk-shape stalk-root  \
# 0            c         n          k           e          e
# 1            c         b          k           e          c
# 2            c         b          n           e          c
# 3            c         n          n           e          e
# 4            w         b          k           t          e
# 5            c         b          n           e          c
# 6            c         b          g           e          c
# 7            c         b          n           e          c
# 8            c         n          p           e          e
# 9            c         b          g           e          c
#
#   stalk-surface-above-ring stalk-surface-below-ring stalk-color-above-ring  \
# 0                        s                        s                      w
# 1                        s                        s                      w
# 2                        s                        s                      w
# 3                        s                        s                      w
# 4                        s                        s                      w
# 5                        s                        s                      w
# 6                        s                        s                      w
# 7                        s                        s                      w
# 8                        s                        s                      w
# 9                        s                        s                      w
#
#   stalk-color-below-ring veil-type veil-color ring-number ring-type  \
# 0                      w         p          w           o         p
# 1                      w         p          w           o         p
# 2                      w         p          w           o         p
# 3                      w         p          w           o         p
# 4                      w         p          w           o         e
# 5                      w         p          w           o         p
# 6                      w         p          w           o         p
# 7                      w         p          w           o         p
# 8                      w         p          w           o         p
# 9                      w         p          w           o         p
#
#   spore-print-color population habitat
# 0                 k          s       u
# 1                 n          n       g
# 2                 n          n       m
# 3                 k          s       u
# 4                 n          a       g
# 5                 k          n       g
# 6                 k          n       m
# 7                 n          s       m
# 8                 k          v       g
# 9                 k          s       m

# %%
print(f"Número de linhas no dataset: {len(df)}")
# Out:
# Número de linhas no dataset: 8124

# %%
# Verificar valores ausentes representados por '?' em todas as colunas
missing_values = (df == '?').sum()

# Filtrar apenas as colunas que possuem valores ausentes
missing_values = missing_values[missing_values > 0]

# Exibir resultado
print("Valores ausentes (representados por '?') por coluna:")
print(missing_values)
# Out:
# Valores ausentes (representados por '?') por coluna:
# stalk-root    2480
# dtype: int64

# %%
# Define um estilo visual
sns.set(style="whitegrid")

# Filtrar apenas colunas categóricas (tipo 'object' ou 'category')
categorical_cols = df.select_dtypes(include=['object', 'category']).columns

# Tamanho do grid (ajustável conforme o número de colunas)
n_cols = 3
n_rows = -(-len(categorical_cols) // n_cols)  # ceil division

# Criar os subplots
fig, axes = plt.subplots(n_rows, n_cols, figsize=(n_cols * 5, n_rows * 4))
axes = axes.flatten()  # achata a matriz de eixos

# Plotar cada gráfico
for i, col in enumerate(categorical_cols):
    sns.countplot(data=df, x=col, ax=axes[i], order=df[col].value_counts().index)
    axes[i].set_title(f'Distribuição de {col}')
    axes[i].tick_params(axis='x', rotation=45)

# Remover eixos extras se houver
for j in range(i + 1, len(axes)):
    fig.delaxes(axes[j])

plt.tight_layout()
plt.show()

# %%
from dython.nominal import associations
import pandas as pd

# Seu DataFrame df já está carregado

# Calcular a matriz de correlação pelo V de Cramer
assoc = associations(df, nominal_columns='all', plot=False)

# A matriz de correlação fica em assoc['corr']
v_de_cramer_matrix = assoc['corr']

associations(df, nominal_columns='all', figsize=(15, 15), cmap='coolwarm')
# Out:
# {'corr':                              class  cap-shape  cap-surface  cap-color  \
#  class                     1.000000   0.244330     0.195997   0.215889
#  cap-shape                 0.244330   1.000000     0.202242   0.168221
#  cap-surface               0.195997   0.202242     1.000000   0.222841
#  cap-color                 0.215889   0.168221     0.222841   1.000000
#  bruises                   0.501188   0.254415     0.133004   0.215101
#  odor                      0.970558   0.243577     0.236416   0.330517
#  gill-attachment           0.127951   0.152989     0.209977   0.245736
#  gill-spacing              0.347897   0.077849     0.337696   0.398593
#  gill-size                 0.539677   0.345956     0.276765   0.469156
#  gill-color                0.679877   0.232274     0.255023   0.280178
#  stalk-shape               0.101170   0.306119     0.076395   0.594499
#  stalk-root                0.406224   0.359388     0.313927   0.383974
#  stalk-surface-above-ring  0.587666   0.158150     0.142861   0.254962
#  stalk-surface-below-ring  0.574551   0.109487     0.168331   0.318457
#  stalk-color-above-ring    0.523943   0.212427     0.250561   0.274663
#  stalk-color-below-ring    0.513799   0.167534     0.255578   0.277404
#  veil-type                 0.000000   0.000000     0.000000   0.000000
#  veil-color                0.152222   0.223124     0.133014   0.147231
#  ring-number               0.214212   0.197883     0.097278   0.336128
#  ring-type                 0.602900   0.206749     0.223669   0.557217
#  spore-print-color         0.752036   0.249101     0.230539   0.284714
#  population                0.486775   0.240074     0.260952   0.304085
#  habitat                   0.439323   0.269842     0.249577   0.325199
#
#                             bruises      odor  gill-attachment  gill-spacing  \
#  class                     0.501188  0.970558         0.127951      0.347897
#  cap-shape                 0.254415  0.243577         0.152989      0.077849
#  cap-surface               0.133004  0.236416         0.209977      0.337696
#  cap-color                 0.215101  0.330517         0.245736      0.398593
#  bruises                   1.000000  0.660201         0.136129      0.298946
#  odor                      0.660201  1.000000         0.259923      0.428647
#  gill-attachment           0.136129  0.259923         1.000000      0.069560
#  gill-spacing              0.298946  0.428647         0.069560      1.000000
#  gill-size                 0.369182  0.760318         0.107581      0.107406
#  gill-color                0.649324  0.388712         0.779340      0.323690
#  stalk-shape               0.098495  0.575023         0.185382      0.079795
#  stalk-root                0.570839  0.619108         0.220201      0.575293
#  stalk-surface-above-ring  0.574898  0.415244         0.092622      0.436872
#  stalk-surface-below-ring  0.566441  0.506395         0.123213      0.414450
#  stalk-color-above-ring    0.482236  0.449330         0.977312      0.399947
#  stalk-color-below-ring    0.491868  0.445795         0.977312      0.374216
#  veil-type                 0.000000  0.000000         0.000000      0.000000
#  veil-color                0.132587  0.099895         0.954963      0.096769
#  ring-number               0.069373  0.742250         0.203183      0.245173
#  ring-type                 0.768218  0.696379         0.249776      0.289482
#  spore-print-color         0.611623  0.395340         0.826353      0.307018
#  population                0.299568  0.373698         0.413362      0.673533
#  habitat                   0.530257  0.368861         0.435707      0.541961
#
#                            gill-size  gill-color  stalk-shape  stalk-root  \
#  class                      0.539677    0.679877     0.101170    0.406224
#  cap-shape                  0.345956    0.232274     0.306119    0.359388
#  cap-surface                0.276765    0.255023     0.076395    0.313927
#  cap-color                  0.469156    0.280178     0.594499    0.383974
#  bruises                    0.369182    0.649324     0.098495    0.570839
#  odor                       0.760318    0.388712     0.575023    0.619108
#  gill-attachment            0.107581    0.779340     0.185382    0.220201
#  gill-spacing               0.107406    0.323690     0.079795    0.575293
#  gill-size                  1.000000    0.783249     0.214033    0.627224
#  gill-color                 0.783249    1.000000     0.611291    0.514065
#  stalk-shape                0.214033    0.611291     1.000000    0.386103
#  stalk-root                 0.627224    0.514065     0.386103    1.000000
#  stalk-surface-above-ring   0.168981    0.352009     0.319471    0.307442
#  stalk-surface-below-ring   0.149698    0.376254     0.367670    0.556125
#  stalk-color-above-ring     0.364753    0.419543     0.536084    0.368331
#  stalk-color-below-ring     0.345772    0.415665     0.548780    0.368462
#  veil-type                  0.000000    0.000000     0.000000    0.000000
#  veil-color                 0.112347    0.452015     0.180869    0.149450
#  ring-number                0.194363    0.442824     0.333291    0.276846
#  ring-type                  0.570257    0.517343     0.614792    0.442274
#  spore-print-color          0.659975    0.484083     0.458414    0.518744
#  population                 0.517249    0.423513     0.455486    0.529233
#  habitat                    0.498616    0.457212     0.417101    0.536186
#
#                            stalk-surface-above-ring  stalk-surface-below-ring  \
#  class                                     0.587666                  0.574551
#  cap-shape                                 0.158150                  0.109487
#  cap-surface                               0.142861                  0.168331
#  cap-color                                 0.254962                  0.318457
#  bruises                                   0.574898                  0.566441
#  odor                                      0.415244                  0.506395
#  gill-attachment                           0.092622                  0.123213
#  gill-spacing                              0.436872                  0.414450
#  gill-size                                 0.168981                  0.149698
#  gill-color                                0.352009                  0.376254
#  stalk-shape                               0.319471                  0.367670
#  stalk-root                                0.307442                  0.556125
#  stalk-surface-above-ring                  1.000000                  0.489650
#  stalk-surface-below-ring                  0.489650                  1.000000
#  stalk-color-above-ring                    0.515859                  0.451998
#  stalk-color-below-ring                    0.431909                  0.460845
#  veil-type                                 0.000000                  0.000000
#  veil-color                                0.339334                  0.117906
#  ring-number                               0.127360                  0.255638
#  ring-type                                 0.453970                  0.518984
#  spore-print-color                         0.418010                  0.420590
#  population                                0.316755                  0.321104
#  habitat                                   0.299380                  0.309131
#
#                            stalk-color-above-ring  stalk-color-below-ring  \
#  class                                   0.523943                0.513799
#  cap-shape                               0.212427                0.167534
#  cap-surface                             0.250561                0.255578
#  cap-color                               0.274663                0.277404
#  bruises                                 0.482236                0.491868
#  odor                                    0.449330                0.445795
#  gill-attachment                         0.977312                0.977312
#  gill-spacing                            0.399947                0.374216
#  gill-size                               0.364753                0.345772
#  gill-color                              0.419543                0.415665
#  stalk-shape                             0.536084                0.548780
#  stalk-root                              0.368331                0.368462
#  stalk-surface-above-ring                0.515859                0.431909
#  stalk-surface-below-ring                0.451998                0.460845
#  stalk-color-above-ring                  1.000000                0.634312
#  stalk-color-below-ring                  0.634312                1.000000
#  veil-type                               0.000000                0.000000
#  veil-color                              0.816044                0.665882
#  ring-number                             0.770740                0.771267
#  ring-type                               0.672056                0.664047
#  spore-print-color                       0.414923                0.410510
#  population                              0.418367                0.415091
#  habitat                                 0.418261                0.416822
#
#                            veil-type  veil-color  ring-number  ring-type  \
#  class                           0.0    0.152222     0.214212   0.602900
#  cap-shape                       0.0    0.223124     0.197883   0.206749
#  cap-surface                     0.0    0.133014     0.097278   0.223669
#  cap-color                       0.0    0.147231     0.336128   0.557217
#  bruises                         0.0    0.132587     0.069373   0.768218
#  odor                            0.0    0.099895     0.742250   0.696379
#  gill-attachment                 0.0    0.954963     0.203183   0.249776
#  gill-spacing                    0.0    0.096769     0.245173   0.289482
#  gill-size                       0.0    0.112347     0.194363   0.570257
#  gill-color                      0.0    0.452015     0.442824   0.517343
#  stalk-shape                     0.0    0.180869     0.333291   0.614792
#  stalk-root                      0.0    0.149450     0.276846   0.442274
#  stalk-surface-above-ring        0.0    0.339334     0.127360   0.453970
#  stalk-surface-below-ring        0.0    0.117906     0.255638   0.518984
#  stalk-color-above-ring          0.0    0.816044     0.770740   0.672056
#  stalk-color-below-ring          0.0    0.665882     0.771267   0.664047
#  veil-type                       0.0    0.000000     0.000000   0.000000
#  veil-color                      0.0    1.000000     0.026509   0.092622
#  ring-number                     0.0    0.026509     1.000000   0.713641
#  ring-type                       0.0    0.092622     0.713641   1.000000
#  spore-print-color               0.0    0.499951     0.367569   0.550017
#  population                      0.0    0.226466     0.417545   0.342205
#  habitat                         0.0    0.270233     0.429743   0.302604
#
#                            spore-print-color  population   habitat
#  class                              0.752036    0.486775  0.439323
#  cap-shape                          0.249101    0.240074  0.269842
#  cap-surface                        0.230539    0.260952  0.249577
#  cap-color                          0.284714    0.304085  0.325199
#  bruises                            0.611623    0.299568  0.530257
#  odor                               0.395340    0.373698  0.368861
#  gill-attachment                    0.826353    0.413362  0.435707
#  gill-spacing                       0.307018    0.673533  0.541961
#  gill-size                          0.659975    0.517249  0.498616
#  gill-color                         0.484083    0.423513  0.457212
#  stalk-shape                        0.458414    0.455486  0.417101
#  stalk-root                         0.518744    0.529233  0.536186
#  stalk-surface-above-ring           0.418010    0.316755  0.299380
#  stalk-surface-below-ring           0.420590    0.321104  0.309131
#  stalk-color-above-ring             0.414923    0.418367  0.418261
#  stalk-color-below-ring             0.410510    0.415091  0.416822
#  veil-type                          0.000000    0.000000  0.000000
#  veil-color                         0.499951    0.226466  0.270233
#  ring-number                        0.367569    0.417545  0.429743
#  ring-type                          0.550017    0.342205  0.302604
#  spore-print-color                  1.000000    0.298200  0.324531
#  population                         0.298200    1.000000  0.506176
#  habitat                            0.324531    0.506176  1.000000  ,
#  'ax': <Axes: >}
