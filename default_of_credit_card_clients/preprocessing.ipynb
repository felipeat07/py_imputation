# %%
import pandas as pd

# Ler o arquivo Excel (a planilha está na segunda aba)
df = pd.read_excel('data/default of credit card clients.xls', header=1)

# Salvar como Parquet
df.to_parquet('data/credit_default.parquet', index=False)

# Verificar se salvou corretamente
print("Parquet salvo com sucesso!")
# Out:
# Parquet salvo com sucesso!

# %%
import pandas as pd

# Carregar o arquivo parquet
df = pd.read_parquet('data/credit_default.parquet')

# Mostrar as 10 primeiras linhas
display(df.head(10))
# Out:
#    ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  PAY_4  \
# 0   1      20000    2          2         1   24      2      2     -1     -1
# 1   2     120000    2          2         2   26     -1      2      0      0
# 2   3      90000    2          2         2   34      0      0      0      0
# 3   4      50000    2          2         1   37      0      0      0      0
# 4   5      50000    1          2         1   57     -1      0     -1      0
# 5   6      50000    1          1         2   37      0      0      0      0
# 6   7     500000    1          1         2   29      0      0      0      0
# 7   8     100000    2          2         2   23      0     -1     -1      0
# 8   9     140000    2          3         1   28      0      0      2      0
# 9  10      20000    1          3         2   35     -2     -2     -2     -2
#
#    ...  BILL_AMT4  BILL_AMT5  BILL_AMT6  PAY_AMT1  PAY_AMT2  PAY_AMT3  \
# ...
